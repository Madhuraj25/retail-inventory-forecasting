# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuraj25/retail-inventory-forecasting/blob/main/class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-beff7b08-ff9c-4d57-991b-8b8addc7b671" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-beff7b08-ff9c-4d57-991b-8b8addc7b671">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip classtwo
# Out:
# Archive:  classtwo.zip
#    creating: test/
#    creating: test/cat/
#   inflating: test/.DS_Store
#   inflating: __MACOSX/test/._.DS_Store
#    creating: test/dog/
#   inflating: test/cat/239.jpg
#   inflating: __MACOSX/test/cat/._239.jpg
#   inflating: test/cat/238.jpg
#   inflating: __MACOSX/test/cat/._238.jpg
#   inflating: test/cat/263.jpg
#   inflating: __MACOSX/test/cat/._263.jpg
#   inflating: test/cat/262.jpg
#   inflating: __MACOSX/test/cat/._262.jpg
#   inflating: test/cat/248.jpg
#   inflating: __MACOSX/test/cat/._248.jpg
#   inflating: test/cat/260.jpg
#   inflating: __MACOSX/test/cat/._260.jpg
#   inflating: test/cat/274.jpg
#   inflating: __MACOSX/test/cat/._274.jpg
#   inflating: test/cat/261.jpg
#   inflating: __MACOSX/test/cat/._261.jpg
#   inflating: test/cat/249.jpg
#   inflating: __MACOSX/test/cat/._249.jpg
#   inflating: test/cat/265.jpg
#   inflating: __MACOSX/test/cat/._265.jpg
#   inflating: test/cat/271.jpg
#   inflating: __MACOSX/test/cat/._271.jpg
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers,models,preprocessing

# %%
# !pwd
# Out:
# /content

# %%
train_ds = preprocessing.image_dataset_from_directory(
    '/content/train',
    image_size=(128, 128)   # tuple, not function
)
# Out:
# Found 99 files belonging to 2 classes.

# %%
test_ds = preprocessing.image_dataset_from_directory('/content/test',image_size=(128,128))
# Out:
# Found 88 files belonging to 2 classes.

# %%
model = models.Sequential(
    [
        layers.Conv2D(16,(3,3),activation='relu',input_shape=(128,128,3)),
        layers.MaxPooling2D(),
        layers.Conv2D(32,(3,3),activation='relu',input_shape=(128,128,3)),
        layers.MaxPooling2D(),
        layers.Conv2D(16,(3,3),activation='relu',input_shape=(128,128,3)),
        layers.MaxPooling2D(),

        layers.Flatten(),
        Layers.Dense(128,activation='relu'),
        Layers.Dense(1,activation='sigmoid')

     ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1078115630.py in <cell line: 0>()
#       9
#      10         layers.Flatten(),
# ---> 11         Layers.Dense(128,activation='relu'),
#      12         Layers.Dense(1,activation='sigmoid')
#      13
#
# NameError: name 'Layers' is not defined

# %%
import tensorflow as tf
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_ds,validation_data=test_ds,epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.6741 - loss: 134.1629 - val_accuracy: 0.6705 - val_loss: 124.4725
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 0.7285 - loss: 126.3963 - val_accuracy: 0.5455 - val_loss: 284.8232
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 0.7233 - loss: 95.0640 - val_accuracy: 0.5455 - val_loss: 243.7896
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.6395 - loss: 122.4279 - val_accuracy: 0.6023 - val_loss: 138.2316
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.7258 - loss: 81.5250 - val_accuracy: 0.5114 - val_loss: 283.3231
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - accuracy: 0.5648 - loss: 294.2628 - val_accuracy: 0.6477 - val_loss: 112.0491
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 429ms/step - accuracy: 0.6575 - loss: 375.4970 - val_accuracy: 0.4773 - val_loss: 537.7741
# Epoch 8/10
# ...
